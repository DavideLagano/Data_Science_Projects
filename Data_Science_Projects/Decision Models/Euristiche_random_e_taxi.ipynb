# %% [markdown]
# # README
#
# In questo file Jupyter si presentano le due euristiche da noi implementate per il problema del Fog Computing.
#
# Per eseguire il codice bisogna usare le funzioni **run_heuristic** per la prima euristica, **multi_agente** per la seconda.
#
# - a) **Parametri da passare alla prima euristica:**
#      - 1) lista di richieste (che può variare ad ogni ciclo)
#      - 2) lista di capacità (una volta fissata, resta costante per tutte le iterazioni)
#      - 3) numero di nodi all'interno del sistema di fog computing
#      - 4) un contatore di scambi
#
# - b) **Parametri da passare alla seconda euristica:**
#      - 1) lista della differenza tra richieste e capacità
#      - 2) lista di richieste (che può variare ad ogni ciclo)
#      - 3) lista di capacità (una volta fissata, resta costante per tutte le iterazioni)
#      - 4) numero di nodi all'interno del sistema di fog computing
#      - 5) un contatore di scambi
#
# **NB**:
# - 1) La lista di richieste deve essere estratta da una distribuzione di Poisson che abbia come media la media della capacità totale del sistema (capacità della cpu e capacità della ram). Il secondo paramentro è il numero di nodi.
# - 2) La lista della capacità viene generata randomicamente in un range che va da 2 a 100 (2 è la richiesta di ram e cpu per ogni richiesta che viene fatta al sistema)
#
# **NB 2**:
# Il codice può essere eseguito anche senza iterazioni, ma, per una migliore simulazione, si consiglia di farle.

# %%
#vengono importate le librerie necessarie
import random
import numpy as np
import pandas as pd
import time

# %% [markdown]
# **Prima Euristica**: *i nodi hanno conoscenza dell'intero sistema*
#
# Vengono di seguito definite le funzioni che serviranno poi per la costruzione della prima euristica *run_heuristic*

# %%
def diff(request,capacity,n):
    difference=[]
    for i in range(0,n):
        difference.append(capacity[i]-request[i])
    
    difference=sorted(difference,reverse=True)
        
    return difference

def iterate(difference,n,count):
    i=0
    while(difference[n-1]<0):
        difference[n-1]=difference[n-1] + difference[i]
        difference[i]=0
        i=i+1
        count+=1
    return difference,count


def fog_computing(difference,n,count):
    if(difference[n-1]>=0):
        print("No changing required:",difference)
    else:
        while(difference[n-1]<0):
            if(abs(difference[n-1]) <= abs(difference[0])):
                difference[0]=difference[0] + difference[n-1]
                difference[n-1]=0
                count+=1
            else:
                difference,count=iterate(difference,n,count)
            
            difference=sorted(difference,reverse=True)
        #print("System completed:",difference)
        print("Numero di scambi prima euristica:",count)
        return count

def run_heuristic(request,capacity,n,count):
    tot_request=sum(request)
    tot_capacity=sum(capacity)
    
    if(tot_request > tot_capacity):
        dif_tot=tot_request-tot_capacity
        i=0
        a=0
        while(dif_tot>0):
            request[i]=request[i]-1
            dif_tot=dif_tot-1
            i=i+1
            a=a+1
            if(i==n-1):
                i=0
        print("System overloaded. {} richieste rigettate".format(a))
        
        #print("Starting the process...")
        differenza=diff(request,capacity,n)
        scambi = fog_computing(differenza,n,count)
    else:
        #print("Starting the process...")
        differenza=diff(request,capacity,n)
        #print('Differenza_prima_euristica:',differenza)
        scambi = fog_computing(differenza,n,count)
    return scambi

# %% [markdown]
# **Seconda euristica**: *i nodi del sistema non hanno informazioni l'uno riguardo all'altro*
#
# Vengono di seguito definite le funzioni che serviranno poi per la costruzione della seconda euristica *multi_agente*

# %%
def diff_multi_agente(request,capacity,n):
    difference=[]
    for i in range(0,n):
        difference.append(capacity[i]-request[i])
    return difference

def multi_agente(differenza, requests, n_richieste, m, scambi):
    indici=[]
    values=[]

    for i in range(len(differenza)):
        if(differenza[i]<0):
            indici.append(i)
            values.append(differenza[i])

    #print('Indici:',indici,'Valori:',values)  
    for i in indici:
        #print("Nodo:{}".format(i))        
        for j in range(len(differenza)):
            if(differenza[j]>=abs(values[indici.index(i)]) and j!=i):
                differenza[j]=differenza[j]+values[indici.index(i)]
                values[indici.index(i)]=0
                differenza[i]=0
                scambi+=1
                #print("Svuotamento completato")
                #print(differenza,values)
                break

        if(values[indici.index(i)]!=0):
            #print('Nodo {} da svuotare in splitting:'.format(i))
            #print(differenza,values)
            while(values[indici.index(i)] < 0):
                if(sum(differenza)>= 0): 
                    for k in range(len(differenza)):
                        if(differenza[k]>0):
                            if(abs(values[indici.index(i)])>differenza[k]):
                                values[indici.index(i)] = values[indici.index(i)] + differenza[k]
                                differenza[k]=0
                                scambi+=1
                            else:
                                differenza[k]=differenza[k]+values[indici.index(i)]
                                values[indici.index(i)]=0
                                scambi+=1
                            #print(differenza,values)
                else:
                    print('System overloaded')
                    if(abs(sum(differenza)) > abs(differenza[i])): 
                        print('{} richieste rigettate'.format(abs(differenza[i])))
                        values[indici.index(i)] = 0
                        differenza[i] = 0
                    else: 
                        print('{} richieste rigettate'.format(abs(sum(differenza))))
                        values[indici.index(i)] = values[indici.index(i)] - sum(differenza)
                        differenza[i] = differenza[i] - sum(differenza)          
            differenza[i]=0
            #print(differenza,values)
            #print('Nodo svuotato')
            
    print('Numero scambi seconda euristica:',scambi)
    return scambi

# %% [markdown]
# Di seguito vengono eseguite 10 iterazioni sia sulla prima che sulla seconda euristica, dove il numero di nodi viene settato a 6 (*m=6*), le richieste di ram e cpu vengono fissate a 2 (*ram_richiesta=2* e *cpu_richiesta=2*), le capacità di ram e cpu vengono settate randomicamente per gli m nodi, in un range che varia tra il numero di richiesta ram (o cpu) e 100.
# Infine, il numero di richieste viene estratto da una distribuzione di Poisson, che ha come media la media della capacità totale del sistema (ovvero capacità della cpu e della ram).

# %%
for iter in range(0,10):
    print("ITERATION {}".format(iter+1))
    m=6
    ram_richiesta = 2
    cpu_richiesta = 2
    ram_capacity=random.sample(range(ram_richiesta,100),m)
    cpu_capacity=random.sample(range(cpu_richiesta,100),m)
    capacity_tot = []
    for i in range(0,m): 
        capacity_tot.append([ram_capacity[i],cpu_capacity[i]])
    n_richieste = [min(x) / ram_richiesta for x in capacity_tot]
    n_richieste = [int(x) for x in n_richieste]
    media_totale = np.mean(n_richieste).tolist()

    richieste=np.random.poisson(media_totale-0.5,m)

    differenza=diff_multi_agente(richieste,n_richieste,m)

    scambi=0
    count=0

    print("Richieste disponibili per nodo:",n_richieste)
    print("Richieste in entrata:",richieste)

    run_heuristic(richieste,n_richieste,m,count)

    multi_agente(differenza, richieste, n_richieste, m, scambi)
# Out:
# ITERATION 1
# Richieste disponibili per nodo: [8, 1, 37, 11, 12, 10]
# Richieste in entrata: [ 8 14 11 20 13 11]
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 2
# Richieste disponibili per nodo: [35, 24, 14, 3, 33, 11]
# Richieste in entrata: [12 23 17 22 24 18]
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 3
# Richieste disponibili per nodo: [8, 3, 4, 9, 15, 9]
# Richieste in entrata: [ 8  8  4  2 10  5]
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 4
# Richieste disponibili per nodo: [3, 23, 1, 35, 26, 18]
# Richieste in entrata: [17 22 15 20 22 15]
# System overloaded. 5 richieste rigettate
# Numero di scambi prima euristica: 5
# System overloaded
# 5 richieste rigettate
# Numero scambi seconda euristica: 5
# ITERATION 5
# Richieste disponibili per nodo: [17, 49, 12, 15, 23, 46]
# Richieste in entrata: [31 32 22 32 24 30]
# System overloaded. 9 richieste rigettate
# Numero di scambi prima euristica: 4
# System overloaded
# 9 richieste rigettate
# Numero scambi seconda euristica: 5
# ITERATION 6
# Richieste disponibili per nodo: [23, 5, 19, 34, 17, 19]
# Richieste in entrata: [20 25 14 15 24 18]
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 5
# ITERATION 7
# Richieste disponibili per nodo: [41, 15, 3, 1, 29, 14]
# Richieste in entrata: [12 14 22 14 27 23]
# System overloaded. 9 richieste rigettate
# Numero di scambi prima euristica: 5
# System overloaded
# 9 richieste rigettate
# Numero scambi seconda euristica: 7
# ITERATION 8
# Richieste disponibili per nodo: [13, 7, 26, 15, 19, 9]
# Richieste in entrata: [13 13 16 14 15 20]
# System overloaded. 2 richieste rigettate
# Numero di scambi prima euristica: 5
# System overloaded
# 2 richieste rigettate
# Numero scambi seconda euristica: 4
# ITERATION 9
# Richieste disponibili per nodo: [7, 26, 8, 43, 3, 10]
# Richieste in entrata: [20 16 17 11 14 16]
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 10
# Richieste disponibili per nodo: [34, 42, 29, 6, 4, 25]
# Richieste in entrata: [18 21 30 22 29 26]
# System overloaded. 6 richieste rigettate
# Numero di scambi prima euristica: 4
# System overloaded
# 6 richieste rigettate
# Numero scambi seconda euristica: 5

# %% [markdown]
# #### Applicazione su un caso reale: richieste di taxi per quartiere a Pechino
#
# Di seguito, vengono applicate le euristiche implementate sopra ad un caso reale (un dataset riguardante le richieste di taxi in 18 quartieri diversi di Pechino). Il dataset è diviso in fasce orarie di mezz'ora. Nei chunks seguenti vengono creati dei dataframe divisi in giorni (*richieste_day_1*,*richieste_day_2*, ecc...).
# I giorni vanno dal 2 all'8 febbraio 2008.
# Ogni dataframe contiene tutte le fasce orarie di un singolo giorno (righe dei dataframe), per tutti i quartieri presi in considerazione (colonne dei dataframe).

# %%
df_originale=pd.read_csv("C:/Users/dasan/Desktop/csv_taxi.csv",sep=",")
df=pd.read_csv("C:/Users/dasan/Desktop/richieste_taxi.csv",sep=",")

# %%
media=(df_originale.groupby(["district"])['taxi_id'].mean()) + 850
district_capacity=round(media)
district_capacity = [int(x) for x in district_capacity]
district_capacity
# Out:
# [1514,
#  12189,
#  5654,
#  2367,
#  8378,
#  2930,
#  5946,
#  5863,
#  1511,
#  1312,
#  1892,
#  3008,
#  1924,
#  3884,
#  3620,
#  3983,
#  7488,
#  1306]

# %%
richieste_day_1=df[0:21]
richieste_day_2=df[21:69].reset_index()
richieste_day_3=df[69:117].reset_index()
richieste_day_4=df[117:165].reset_index()
richieste_day_5=df[165:213].reset_index()
richieste_day_6=df[213:261].reset_index()
richieste_day_7=df[261:len(df)].reset_index()

# %%
quartieri=['quartiere_0','quartiere_1','quartiere_2','quartiere_3','quartiere_4','quartiere_5',
          'quartiere_6','quartiere_7','quartiere_8','quartiere_9','quartiere_10','quartiere_11',
           'quartiere_12','quartiere_13','quartiere_14','quartiere_15','quartiere_16','quartiere_17']

# %% [markdown]
# Di seguito vengono eseguite le due euristiche, per ogni giorno, su tutte le fasce orarie e su tutti i quartieri, per poi effettuare una successiva analisi dei risultati.

# %%
count=0
scambi=0
m=18
richieste=[]

for i in range(len(richieste_day_1)):
    for j in range(len(quartieri)):
        richieste.append(richieste_day_1['quartiere_{}'.format(j)][i])
    
    req=richieste.copy()
    
    print('ITERATION {}'.format(i))

    changes_1 = run_heuristic(richieste,district_capacity,m,count)
    
    differenza=diff_multi_agente(req,district_capacity,m)
    changes = multi_agente(differenza, req, district_capacity, m, scambi)
    time.sleep(10)
    richieste=[]
# Out:
# ITERATION 0
# System overloaded. 2023 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 2023 richieste rigettate
# Numero scambi seconda euristica: 44
# ITERATION 1
# Numero di scambi prima euristica: 16
# Numero scambi seconda euristica: 34
# ITERATION 2
# Numero di scambi prima euristica: 15
# Numero scambi seconda euristica: 33
# ITERATION 3
# Numero di scambi prima euristica: 11
# Numero scambi seconda euristica: 39
# ITERATION 4
# Numero di scambi prima euristica: 11
# Numero scambi seconda euristica: 39
# ITERATION 5
# System overloaded. 1556 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 1556 richieste rigettate
# Numero scambi seconda euristica: 35
# ITERATION 6
# System overloaded. 187 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 187 richieste rigettate
# Numero scambi seconda euristica: 33
# ITERATION 7
# Numero di scambi prima euristica: 15
# Numero scambi seconda euristica: 33
# ITERATION 8
# System overloaded. 1623 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 1623 richieste rigettate
# Numero scambi seconda euristica: 36
# ITERATION 9
# System overloaded. 543 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 543 richieste rigettate
# Numero scambi seconda euristica: 34
# ITERATION 10
# System overloaded. 3124 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 3124 richieste rigettate
# Numero scambi seconda euristica: 35
# ITERATION 11
# System overloaded. 10041 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 8523 richieste rigettate
# System overloaded
# 1518 richieste rigettate
# Numero scambi seconda euristica: 31
# ITERATION 12
# System overloaded. 9457 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 7757 richieste rigettate
# System overloaded
# 1700 richieste rigettate
# Numero scambi seconda euristica: 40
# ITERATION 13
# System overloaded. 9594 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 8742 richieste rigettate
# System overloaded
# 852 richieste rigettate
# Numero scambi seconda euristica: 25
# ITERATION 14
# System overloaded. 4624 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 4624 richieste rigettate
# Numero scambi seconda euristica: 31
# ITERATION 15
# Numero di scambi prima euristica: 13
# Numero scambi seconda euristica: 28
# ITERATION 16
# Numero di scambi prima euristica: 16
# Numero scambi seconda euristica: 31
# ITERATION 17
# Numero di scambi prima euristica: 9
# Numero scambi seconda euristica: 25
# ITERATION 18
# Numero di scambi prima euristica: 12
# Numero scambi seconda euristica: 28
# ITERATION 19
# Numero di scambi prima euristica: 7
# Numero scambi seconda euristica: 17
# ITERATION 20
# Numero di scambi prima euristica: 6
# Numero scambi seconda euristica: 6

# %%
count=0
scambi=0
m=18
richieste=[]

for i in range(len(richieste_day_2)):
    for j in range(len(quartieri)):
        richieste.append(richieste_day_2['quartiere_{}'.format(j)][i])
    
    req=richieste.copy()
    
    print('ITERATION {}'.format(i))

    changes_1 = run_heuristic(richieste,district_capacity,m,count)
    
    differenza=diff_multi_agente(req,district_capacity,m)
    changes = multi_agente(differenza, req, district_capacity, m, scambi)
    time.sleep(10)
    richieste=[]
# Out:
# ITERATION 0
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 1
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 2
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 3
# No changing required: [2557, 1739, 1521, 1345, 1336, 1280, 1280, 1234, 1213, 1157, 1147, 1065, 968, 919, 890, 799, 627, 190]
# Numero scambi seconda euristica: 0
# ITERATION 4
# No changing required: [7113, 4993, 4827, 3958, 3658, 3044, 2810, 2790, 2411, 2389, 2137, 1790, 1615, 1373, 1372, 1294, 1074, 1070]
# Numero scambi seconda euristica: 0
# ITERATION 5
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 6
# No changing required: [3811, 2696, 2602, 2596, 2326, 2061, 1749, 1617, 1287, 1164, 1111, 1093, 952, 857, 701, 602, 528, 419]
# Numero scambi seconda euristica: 0
# ITERATION 7
# No changing required: [4784, 4688, 3701, 3412, 3260, 2654, 2374, 2032, 1710, 1592, 1542, 1292, 1245, 1213, 1059, 946, 938, 789]
# Numero scambi seconda euristica: 0
# ITERATION 8
# No changing required: [4985, 3474, 3382, 3102, 3022, 2620, 2232, 1865, 1645, 1310, 1298, 1290, 978, 974, 899, 874, 590, 325]
# Numero scambi seconda euristica: 0
# ITERATION 9
# No changing required: [4505, 3260, 3197, 3025, 2535, 2317, 2160, 1792, 1661, 1291, 1122, 1001, 943, 936, 929, 837, 795, 509]
# Numero scambi seconda euristica: 0
# ITERATION 10
# No changing required: [4527, 3100, 2852, 2792, 2775, 2532, 2263, 1894, 1661, 1285, 1116, 977, 901, 891, 858, 815, 763, 591]
# Numero scambi seconda euristica: 0
# ITERATION 11
# No changing required: [4928, 3668, 3296, 2953, 2823, 2557, 2396, 1968, 1642, 1285, 1213, 1094, 1070, 1047, 926, 906, 846, 559]
# Numero scambi seconda euristica: 0
# ITERATION 12
# No changing required: [4760, 4064, 3498, 3147, 2906, 2535, 2449, 1742, 1660, 1280, 1254, 1163, 1125, 988, 885, 857, 816, 300]
# Numero scambi seconda euristica: 0
# ITERATION 13
# No changing required: [5023, 4796, 3372, 3210, 3192, 2928, 2576, 1835, 1713, 1450, 1428, 1362, 1279, 1136, 1087, 933, 864, 425]
# Numero scambi seconda euristica: 0
# ITERATION 14
# No changing required: [4884, 4599, 4416, 3508, 3132, 2631, 2133, 1715, 1593, 1332, 1310, 1291, 1263, 1177, 1160, 963, 918, 494]
# Numero scambi seconda euristica: 0
# ITERATION 15
# No changing required: [5457, 5023, 4847, 3474, 3252, 2682, 2141, 2025, 1751, 1745, 1708, 1285, 1218, 1119, 1041, 940, 756, 652]
# Numero scambi seconda euristica: 0
# ITERATION 16
# No changing required: [4777, 4497, 3698, 3630, 2677, 2669, 2187, 1851, 1762, 1754, 1719, 1323, 1272, 1272, 1086, 982, 662, 352]
# Numero scambi seconda euristica: 0
# ITERATION 17
# No changing required: [3136, 3028, 2838, 2515, 2198, 2092, 1756, 1510, 1381, 1279, 1209, 1025, 881, 790, 613, 528, 319, 208]
# Numero scambi seconda euristica: 0
# ITERATION 18
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 19
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 17
# ITERATION 20
# Numero di scambi prima euristica: 5
# Numero scambi seconda euristica: 17
# ITERATION 21
# Numero di scambi prima euristica: 10
# Numero scambi seconda euristica: 25
# ITERATION 22
# Numero di scambi prima euristica: 12
# Numero scambi seconda euristica: 31
# ITERATION 23
# Numero di scambi prima euristica: 12
# Numero scambi seconda euristica: 31
# ITERATION 24
# Numero di scambi prima euristica: 7
# Numero scambi seconda euristica: 17
# ITERATION 25
# System overloaded. 3514 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 3514 richieste rigettate
# Numero scambi seconda euristica: 36
# ITERATION 26
# System overloaded. 8946 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 8946 richieste rigettate
# Numero scambi seconda euristica: 44
# ITERATION 27
# System overloaded. 5947 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 5947 richieste rigettate
# Numero scambi seconda euristica: 37
# ITERATION 28
# System overloaded. 4098 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 4098 richieste rigettate
# Numero scambi seconda euristica: 39
# ITERATION 29
# System overloaded. 7369 richieste rigettate
# Numero di scambi prima euristica: 16
# System overloaded
# 5507 richieste rigettate
# System overloaded
# 1862 richieste rigettate
# Numero scambi seconda euristica: 48
# ITERATION 30
# System overloaded. 6010 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 6010 richieste rigettate
# Numero scambi seconda euristica: 40
# ITERATION 31
# System overloaded. 6096 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 6096 richieste rigettate
# Numero scambi seconda euristica: 41
# ITERATION 32
# System overloaded. 4572 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 4572 richieste rigettate
# Numero scambi seconda euristica: 44
# ITERATION 33
# System overloaded. 7708 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 5990 richieste rigettate
# System overloaded
# 1718 richieste rigettate
# Numero scambi seconda euristica: 30
# ITERATION 34
# System overloaded. 10201 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 5856 richieste rigettate
# System overloaded
# 4345 richieste rigettate
# Numero scambi seconda euristica: 42
# ITERATION 35
# System overloaded. 8773 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 6432 richieste rigettate
# System overloaded
# 2341 richieste rigettate
# Numero scambi seconda euristica: 42
# ITERATION 36
# System overloaded. 9894 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 6854 richieste rigettate
# System overloaded
# 3040 richieste rigettate
# Numero scambi seconda euristica: 41
# ITERATION 37
# System overloaded. 11102 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 8233 richieste rigettate
# System overloaded
# 2869 richieste rigettate
# Numero scambi seconda euristica: 40
# ITERATION 38
# System overloaded. 11169 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 7254 richieste rigettate
# System overloaded
# 3773 richieste rigettate
# System overloaded
# 142 richieste rigettate
# Numero scambi seconda euristica: 22
# ITERATION 39
# System overloaded. 13460 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 7795 richieste rigettate
# System overloaded
# 5395 richieste rigettate
# System overloaded
# 270 richieste rigettate
# Numero scambi seconda euristica: 29
# ITERATION 40
# System overloaded. 12572 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 7442 richieste rigettate
# System overloaded
# 5130 richieste rigettate
# Numero scambi seconda euristica: 39
# ITERATION 41
# System overloaded. 9249 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 7103 richieste rigettate
# System overloaded
# 2146 richieste rigettate
# Numero scambi seconda euristica: 38
# ITERATION 42
# System overloaded. 7718 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 6208 richieste rigettate
# System overloaded
# 1510 richieste rigettate
# Numero scambi seconda euristica: 36
# ITERATION 43
# System overloaded. 2643 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 2643 richieste rigettate
# Numero scambi seconda euristica: 44
# ITERATION 44
# Numero di scambi prima euristica: 13
# Numero scambi seconda euristica: 36
# ITERATION 45
# Numero di scambi prima euristica: 14
# Numero scambi seconda euristica: 26
# ITERATION 46
# Numero di scambi prima euristica: 6
# Numero scambi seconda euristica: 6
# ITERATION 47
# Numero di scambi prima euristica: 6
# Numero scambi seconda euristica: 6

# %%
count=0
scambi=0
m=18
richieste=[]

for i in range(len(richieste_day_3)):
    for j in range(len(quartieri)):
        richieste.append(richieste_day_3['quartiere_{}'.format(j)][i])
    
    req=richieste.copy()
    
    print('ITERATION {}'.format(i))

    changes_1 = run_heuristic(richieste,district_capacity,m,count)
    
    differenza=diff_multi_agente(req,district_capacity,m)
    changes = multi_agente(differenza, req, district_capacity, m, scambi)
    time.sleep(10)
    richieste=[]
# Out:
# ITERATION 0
# Numero di scambi prima euristica: 6
# Numero scambi seconda euristica: 6
# ITERATION 1
# Numero di scambi prima euristica: 6
# Numero scambi seconda euristica: 6
# ITERATION 2
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 3
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 4
# No changing required: [3301, 2651, 2219, 2130, 2013, 1866, 1750, 1668, 1520, 1295, 1280, 1159, 991, 956, 913, 727, 714, 621]
# Numero scambi seconda euristica: 0
# ITERATION 5
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 6
# No changing required: [3341, 2558, 1894, 1868, 1708, 1591, 1536, 1359, 1295, 1168, 907, 828, 826, 731, 641, 602, 602, 270]
# Numero scambi seconda euristica: 0
# ITERATION 7
# No changing required: [3785, 2622, 2508, 2483, 2213, 1656, 1446, 1383, 1380, 1289, 1029, 852, 829, 808, 733, 730, 562, 150]
# Numero scambi seconda euristica: 0
# ITERATION 8
# No changing required: [4427, 3098, 2882, 2521, 2493, 2474, 2087, 1721, 1659, 1292, 992, 891, 823, 818, 813, 685, 591, 434]
# Numero scambi seconda euristica: 0
# ITERATION 9
# No changing required: [4490, 2893, 2707, 2644, 2523, 2459, 2426, 1729, 1663, 1295, 1122, 943, 841, 817, 806, 764, 580, 433]
# Numero scambi seconda euristica: 0
# ITERATION 10
# No changing required: [4766, 3530, 3306, 2899, 2725, 2553, 2498, 1916, 1612, 1293, 1053, 1038, 1034, 889, 887, 835, 640, 536]
# Numero scambi seconda euristica: 0
# ITERATION 11
# No changing required: [4857, 3995, 3834, 3072, 2995, 2905, 2547, 2039, 1708, 1299, 1124, 1110, 918, 904, 883, 877, 627, 607]
# Numero scambi seconda euristica: 0
# ITERATION 12
# No changing required: [4669, 4195, 3954, 2963, 2904, 2817, 2541, 1875, 1702, 1263, 1089, 846, 845, 841, 742, 599, 599, 553]
# Numero scambi seconda euristica: 0
# ITERATION 13
# No changing required: [4798, 3542, 3457, 2919, 2791, 2541, 2440, 1696, 1437, 1299, 1158, 857, 839, 825, 569, 567, 418, 326]
# Numero scambi seconda euristica: 0
# ITERATION 14
# No changing required: [4292, 3777, 3091, 2672, 2517, 2439, 2392, 1708, 1295, 1290, 930, 852, 812, 646, 630, 557, 552, 43]
# Numero scambi seconda euristica: 0
# ITERATION 15
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 16
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 17
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 18
# Numero di scambi prima euristica: 13
# Numero scambi seconda euristica: 30
# ITERATION 19
# System overloaded. 6461 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 6461 richieste rigettate
# Numero scambi seconda euristica: 40
# ITERATION 20
# System overloaded. 7757 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 7757 richieste rigettate
# Numero scambi seconda euristica: 40
# ITERATION 21
# System overloaded. 571 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 571 richieste rigettate
# Numero scambi seconda euristica: 33
# ITERATION 22
# System overloaded. 6247 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 6247 richieste rigettate
# Numero scambi seconda euristica: 37
# ITERATION 23
# System overloaded. 6247 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 6247 richieste rigettate
# Numero scambi seconda euristica: 37
# ITERATION 24
# System overloaded. 10666 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 10666 richieste rigettate
# Numero scambi seconda euristica: 43
# ITERATION 25
# System overloaded. 13078 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 10978 richieste rigettate
# System overloaded
# 2100 richieste rigettate
# Numero scambi seconda euristica: 38
# ITERATION 26
# System overloaded. 12504 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 8316 richieste rigettate
# System overloaded
# 3385 richieste rigettate
# System overloaded
# 803 richieste rigettate
# Numero scambi seconda euristica: 27
# ITERATION 27
# System overloaded. 9480 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 6141 richieste rigettate
# System overloaded
# 3339 richieste rigettate
# Numero scambi seconda euristica: 38
# ITERATION 28
# System overloaded. 11273 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 8477 richieste rigettate
# System overloaded
# 2796 richieste rigettate
# Numero scambi seconda euristica: 39
# ITERATION 29
# System overloaded. 7544 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 7176 richieste rigettate
# System overloaded
# 368 richieste rigettate
# Numero scambi seconda euristica: 35
# ITERATION 30
# Numero di scambi prima euristica: 12
# Numero scambi seconda euristica: 32
# ITERATION 31
# Numero di scambi prima euristica: 12
# Numero scambi seconda euristica: 36
# ITERATION 32
# System overloaded. 2394 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 2394 richieste rigettate
# Numero scambi seconda euristica: 37
# ITERATION 33
# System overloaded. 5062 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 5062 richieste rigettate
# Numero scambi seconda euristica: 51
# ITERATION 34
# System overloaded. 10001 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 7080 richieste rigettate
# System overloaded
# 2921 richieste rigettate
# Numero scambi seconda euristica: 47
# ITERATION 35
# System overloaded. 10855 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 7682 richieste rigettate
# System overloaded
# 3173 richieste rigettate
# Numero scambi seconda euristica: 48
# ITERATION 36
# System overloaded. 7243 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 7187 richieste rigettate
# System overloaded
# 56 richieste rigettate
# Numero scambi seconda euristica: 38
# ITERATION 37
# System overloaded. 5108 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 5108 richieste rigettate
# Numero scambi seconda euristica: 48
# ITERATION 38
# System overloaded. 5453 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 5453 richieste rigettate
# Numero scambi seconda euristica: 47
# ITERATION 39
# System overloaded. 7509 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 6150 richieste rigettate
# System overloaded
# 1359 richieste rigettate
# Numero scambi seconda euristica: 37
# ITERATION 40
# System overloaded. 3676 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 3676 richieste rigettate
# Numero scambi seconda euristica: 33
# ITERATION 41
# System overloaded. 1364 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 1364 richieste rigettate
# Numero scambi seconda euristica: 36
# ITERATION 42
# Numero di scambi prima euristica: 5
# Numero scambi seconda euristica: 5
# ITERATION 43
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 44
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 45
# Numero di scambi prima euristica: 6
# Numero scambi seconda euristica: 6
# ITERATION 46
# Numero di scambi prima euristica: 7
# Numero scambi seconda euristica: 7
# ITERATION 47
# Numero di scambi prima euristica: 5
# Numero scambi seconda euristica: 5

# %%
count=0
scambi=0
m=18
richieste=[]

for i in range(len(richieste_day_4)):
    for j in range(len(quartieri)):
        richieste.append(richieste_day_4['quartiere_{}'.format(j)][i])
    
    req=richieste.copy()
    
    print('ITERATION {}'.format(i))

    changes_1 = run_heuristic(richieste,district_capacity,m,count)
    
    differenza=diff_multi_agente(req,district_capacity,m)
    changes = multi_agente(differenza, req, district_capacity, m, scambi)
    time.sleep(10)
    richieste=[]
# Out:
# ITERATION 0
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 1
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 2
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 3
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 4
# No changing required: [10019, 7110, 6578, 5266, 5171, 4917, 3369, 3231, 3134, 2916, 2594, 2034, 1852, 1770, 1440, 1331, 1282, 1235]
# Numero scambi seconda euristica: 0
# ITERATION 5
# No changing required: [4268, 3788, 3480, 2943, 2832, 2831, 2541, 1785, 1655, 1561, 1450, 1294, 1176, 1156, 1120, 981, 833, 636]
# Numero scambi seconda euristica: 0
# ITERATION 6
# No changing required: [3719, 3231, 3190, 2791, 2576, 2415, 2332, 1630, 1525, 1288, 1210, 1148, 1121, 879, 797, 733, 650, 67]
# Numero scambi seconda euristica: 0
# ITERATION 7
# No changing required: [3994, 3821, 3502, 2910, 2902, 2541, 2423, 1874, 1635, 1328, 1233, 1144, 1097, 951, 894, 883, 700, 512]
# Numero scambi seconda euristica: 0
# ITERATION 8
# No changing required: [3983, 3689, 3676, 3059, 2998, 2592, 2452, 1754, 1567, 1277, 1210, 1023, 991, 868, 798, 605, 588, 518]
# Numero scambi seconda euristica: 0
# ITERATION 9
# No changing required: [4356, 4249, 4236, 3277, 3000, 2976, 2401, 1993, 1585, 1290, 1215, 1103, 1063, 1055, 772, 709, 642, 597]
# Numero scambi seconda euristica: 0
# ITERATION 10
# No changing required: [4327, 4176, 4147, 3146, 3006, 2472, 2432, 2126, 1540, 1283, 1156, 1018, 944, 709, 517, 408, 284, 127]
# Numero scambi seconda euristica: 0
# ITERATION 11
# No changing required: [4404, 4171, 3995, 3792, 3415, 2695, 2440, 2124, 1522, 1295, 1280, 1222, 1019, 835, 811, 589, 588, 507]
# Numero scambi seconda euristica: 0
# ITERATION 12
# No changing required: [4479, 3969, 3859, 3627, 2908, 2784, 2355, 2006, 1534, 1288, 1281, 1071, 1007, 792, 772, 558, 518, 346]
# Numero scambi seconda euristica: 0
# ITERATION 13
# No changing required: [4496, 4440, 3879, 3391, 3198, 2787, 2385, 1856, 1570, 1450, 1275, 1248, 1194, 850, 830, 648, 640, 523]
# Numero scambi seconda euristica: 0
# ITERATION 14
# No changing required: [3963, 3480, 3382, 3111, 2772, 2753, 2462, 1622, 1279, 1167, 1140, 1052, 944, 845, 791, 620, 514, 488]
# Numero scambi seconda euristica: 0
# ITERATION 15
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 16
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 17
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 18
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 19
# Numero di scambi prima euristica: 11
# Numero scambi seconda euristica: 24
# ITERATION 20
# System overloaded. 3142 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 3142 richieste rigettate
# Numero scambi seconda euristica: 31
# ITERATION 21
# System overloaded. 4270 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 4270 richieste rigettate
# Numero scambi seconda euristica: 39
# ITERATION 22
# System overloaded. 6659 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 6368 richieste rigettate
# System overloaded
# 291 richieste rigettate
# Numero scambi seconda euristica: 32
# ITERATION 23
# System overloaded. 6659 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 6368 richieste rigettate
# System overloaded
# 291 richieste rigettate
# Numero scambi seconda euristica: 32
# ITERATION 24
# System overloaded. 9979 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 7802 richieste rigettate
# System overloaded
# 2177 richieste rigettate
# Numero scambi seconda euristica: 37
# ITERATION 25
# System overloaded. 11100 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 7515 richieste rigettate
# System overloaded
# 3206 richieste rigettate
# System overloaded
# 379 richieste rigettate
# Numero scambi seconda euristica: 29
# ITERATION 26
# System overloaded. 11681 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 7284 richieste rigettate
# System overloaded
# 2224 richieste rigettate
# System overloaded
# 2173 richieste rigettate
# Numero scambi seconda euristica: 40
# ITERATION 27
# System overloaded. 8283 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 6195 richieste rigettate
# System overloaded
# 2088 richieste rigettate
# Numero scambi seconda euristica: 40
# ITERATION 28
# System overloaded. 3145 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 3145 richieste rigettate
# Numero scambi seconda euristica: 49
# ITERATION 29
# System overloaded. 7853 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 4567 richieste rigettate
# System overloaded
# 2578 richieste rigettate
# System overloaded
# 708 richieste rigettate
# Numero scambi seconda euristica: 27
# ITERATION 30
# System overloaded. 4213 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 4213 richieste rigettate
# Numero scambi seconda euristica: 48
# ITERATION 31
# System overloaded. 7436 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 4916 richieste rigettate
# System overloaded
# 2520 richieste rigettate
# Numero scambi seconda euristica: 42
# ITERATION 32
# System overloaded. 6186 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 4507 richieste rigettate
# System overloaded
# 1679 richieste rigettate
# Numero scambi seconda euristica: 44
# ITERATION 33
# System overloaded. 6497 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 4448 richieste rigettate
# System overloaded
# 2049 richieste rigettate
# Numero scambi seconda euristica: 44
# ITERATION 34
# System overloaded. 3136 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 3136 richieste rigettate
# Numero scambi seconda euristica: 50
# ITERATION 35
# System overloaded. 5744 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 2910 richieste rigettate
# System overloaded
# 1966 richieste rigettate
# System overloaded
# 868 richieste rigettate
# Numero scambi seconda euristica: 37
# ITERATION 36
# System overloaded. 1265 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 1265 richieste rigettate
# Numero scambi seconda euristica: 37
# ITERATION 37
# System overloaded. 9157 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 4406 richieste rigettate
# System overloaded
# 1705 richieste rigettate
# System overloaded
# 2160 richieste rigettate
# System overloaded
# 886 richieste rigettate
# Numero scambi seconda euristica: 27
# ITERATION 38
# System overloaded. 6370 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 4785 richieste rigettate
# System overloaded
# 1585 richieste rigettate
# Numero scambi seconda euristica: 47
# ITERATION 39
# System overloaded. 7793 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 5824 richieste rigettate
# System overloaded
# 1805 richieste rigettate
# System overloaded
# 164 richieste rigettate
# Numero scambi seconda euristica: 33
# ITERATION 40
# System overloaded. 2136 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 2136 richieste rigettate
# Numero scambi seconda euristica: 30
# ITERATION 41
# System overloaded. 3674 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 2715 richieste rigettate
# System overloaded
# 959 richieste rigettate
# Numero scambi seconda euristica: 29
# ITERATION 42
# Numero di scambi prima euristica: 13
# Numero scambi seconda euristica: 33
# ITERATION 43
# Numero di scambi prima euristica: 7
# Numero scambi seconda euristica: 27
# ITERATION 44
# Numero di scambi prima euristica: 6
# Numero scambi seconda euristica: 17
# ITERATION 45
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 46
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 47
# No changing required: [2229, 1983, 1653, 1302, 1132, 1096, 1042, 1013, 901, 826, 825, 803, 765, 759, 539, 538, 384, 42]
# Numero scambi seconda euristica: 0

# %%
count=0
scambi=0
m=18
richieste=[]

for i in range(len(richieste_day_5)):
    for j in range(len(quartieri)):
        richieste.append(richieste_day_5['quartiere_{}'.format(j)][i])
    
    req=richieste.copy()
    
    print('ITERATION {}'.format(i))

    changes_1 = run_heuristic(richieste,district_capacity,m,count)
    
    differenza=diff_multi_agente(req,district_capacity,m)
    changes = multi_agente(differenza, req, district_capacity, m, scambi)
    time.sleep(10)
    richieste=[]
# Out:
# ITERATION 0
# No changing required: [2238, 1677, 1511, 1243, 1107, 1027, 1023, 973, 892, 868, 855, 802, 637, 609, 572, 559, 315, 280]
# Numero scambi seconda euristica: 0
# ITERATION 1
# No changing required: [3430, 3163, 2761, 2396, 2027, 1558, 1242, 1124, 1042, 951, 929, 903, 895, 689, 605, 601, 458, 345]
# Numero scambi seconda euristica: 0
# ITERATION 2
# No changing required: [3582, 3333, 3234, 2496, 2133, 1780, 1255, 1157, 1094, 1016, 943, 943, 911, 893, 795, 618, 596, 278]
# Numero scambi seconda euristica: 0
# ITERATION 3
# No changing required: [4078, 3784, 3466, 2861, 2651, 2582, 1214, 1047, 1030, 953, 944, 889, 834, 733, 703, 649, 475, 333]
# Numero scambi seconda euristica: 0
# ITERATION 4
# No changing required: [5694, 4709, 4663, 3619, 3355, 2928, 1532, 1512, 1473, 1154, 1045, 1034, 917, 906, 874, 828, 671, 629]
# Numero scambi seconda euristica: 0
# ITERATION 5
# No changing required: [4998, 4730, 4108, 3130, 2961, 2566, 1241, 1120, 1060, 955, 944, 885, 617, 609, 492, 488, 463, 239]
# Numero scambi seconda euristica: 0
# ITERATION 6
# No changing required: [5617, 5032, 4613, 3672, 3299, 3186, 1297, 1205, 1149, 1009, 974, 950, 647, 566, 551, 531, 463, 410]
# Numero scambi seconda euristica: 0
# ITERATION 7
# No changing required: [5466, 5208, 5174, 3660, 3546, 3512, 1475, 1190, 1173, 1153, 966, 823, 780, 621, 514, 509, 487, 436]
# Numero scambi seconda euristica: 0
# ITERATION 8
# No changing required: [5923, 5574, 5434, 3844, 3780, 3655, 1513, 1260, 1111, 1094, 1071, 836, 662, 620, 474, 470, 469, 462]
# Numero scambi seconda euristica: 0
# ITERATION 9
# No changing required: [6706, 5499, 5134, 3842, 3685, 3553, 1344, 1239, 1215, 1184, 1161, 792, 701, 656, 646, 562, 456, 434]
# Numero scambi seconda euristica: 0
# ITERATION 10
# No changing required: [6755, 5361, 5160, 3922, 3653, 3607, 1630, 1301, 1251, 1178, 1018, 854, 683, 632, 584, 544, 498, 412]
# Numero scambi seconda euristica: 0
# ITERATION 11
# No changing required: [7473, 5848, 5642, 4138, 3841, 3732, 1778, 1629, 1272, 1150, 1141, 812, 773, 651, 623, 615, 515, 452]
# Numero scambi seconda euristica: 0
# ITERATION 12
# No changing required: [7139, 5715, 5564, 3971, 3745, 3646, 1634, 1510, 1275, 1089, 974, 897, 722, 593, 550, 544, 471, 386]
# Numero scambi seconda euristica: 0
# ITERATION 13
# No changing required: [7016, 5560, 5253, 3981, 3660, 3445, 1400, 1336, 1231, 1022, 932, 740, 647, 595, 580, 476, 450, 275]
# Numero scambi seconda euristica: 0
# ITERATION 14
# No changing required: [6991, 5826, 5294, 3731, 3713, 3379, 1376, 1241, 1092, 1091, 885, 827, 745, 642, 640, 601, 520, 324]
# Numero scambi seconda euristica: 0
# ITERATION 15
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 16
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 17
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 18
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 19
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 20
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 21
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 22
# Numero di scambi prima euristica: 5
# Numero scambi seconda euristica: 5
# ITERATION 23
# Numero di scambi prima euristica: 5
# Numero scambi seconda euristica: 5
# ITERATION 24
# Numero di scambi prima euristica: 6
# Numero scambi seconda euristica: 17
# ITERATION 25
# Numero di scambi prima euristica: 8
# Numero scambi seconda euristica: 8
# ITERATION 26
# Numero di scambi prima euristica: 9
# Numero scambi seconda euristica: 27
# ITERATION 27
# Numero di scambi prima euristica: 5
# Numero scambi seconda euristica: 5
# ITERATION 28
# Numero di scambi prima euristica: 5
# Numero scambi seconda euristica: 5
# ITERATION 29
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 30
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 31
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 32
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 33
# Numero di scambi prima euristica: 5
# Numero scambi seconda euristica: 5
# ITERATION 34
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 35
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 36
# Numero di scambi prima euristica: 5
# Numero scambi seconda euristica: 17
# ITERATION 37
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 17
# ITERATION 38
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 39
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 40
# Numero di scambi prima euristica: 5
# Numero scambi seconda euristica: 5
# ITERATION 41
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 42
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 43
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 44
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 45
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 46
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 47
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2

# %%
count=0
scambi=0
m=18
richieste=[]

for i in range(len(richieste_day_6)):
    for j in range(len(quartieri)):
        richieste.append(richieste_day_6['quartiere_{}'.format(j)][i])
    
    req=richieste.copy()
    
    print('ITERATION {}'.format(i))

    changes_1 = run_heuristic(richieste,district_capacity,m,count)
    
    differenza=diff_multi_agente(req,district_capacity,m)
    changes = multi_agente(differenza, req, district_capacity, m, scambi)
    time.sleep(10)
    richieste=[]
# Out:
# ITERATION 0
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 1
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 2
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 3
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 4
# No changing required: [8598, 6085, 5601, 4302, 4291, 3751, 2652, 2065, 1764, 1422, 1083, 1003, 996, 795, 699, 646, 486, 328]
# Numero scambi seconda euristica: 0
# ITERATION 5
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 6
# Numero di scambi prima euristica: 1
# Numero scambi seconda euristica: 1
# ITERATION 7
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 8
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 9
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 10
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 11
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 12
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 13
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 14
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 15
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 16
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 17
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 18
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 19
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 20
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 21
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 22
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 23
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 24
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 25
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 26
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 27
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 28
# Numero di scambi prima euristica: 6
# Numero scambi seconda euristica: 6
# ITERATION 29
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 30
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 31
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 32
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 33
# Numero di scambi prima euristica: 5
# Numero scambi seconda euristica: 5
# ITERATION 34
# Numero di scambi prima euristica: 5
# Numero scambi seconda euristica: 5
# ITERATION 35
# Numero di scambi prima euristica: 5
# Numero scambi seconda euristica: 5
# ITERATION 36
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 17
# ITERATION 37
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 17
# ITERATION 38
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 39
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 17
# ITERATION 40
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 41
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 42
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 43
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 44
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 45
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 46
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 47
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3

# %%
count=0
scambi=0
m=18
richieste=[]

for i in range(len(richieste_day_7)):
    for j in range(len(quartieri)):
        richieste.append(richieste_day_7['quartiere_{}'.format(j)][i])
    
    req=richieste.copy()
    
    print('ITERATION {}'.format(i))

    changes_1 = run_heuristic(richieste,district_capacity,m,count)
    
    differenza=diff_multi_agente(req,district_capacity,m)
    changes = multi_agente(differenza, req, district_capacity, m, scambi)
    time.sleep(10)
    richieste=[]
# Out:
# ITERATION 0
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 1
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 2
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 3
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 4
# No changing required: [10964, 7723, 6881, 5470, 5334, 5098, 3339, 3293, 3045, 2252, 2191, 1913, 1734, 1550, 1387, 1209, 1206, 1088]
# Numero scambi seconda euristica: 0
# ITERATION 5
# No changing required: [9273, 6941, 6060, 5085, 4869, 4677, 2575, 2381, 2296, 1556, 1372, 1197, 1142, 1136, 1069, 1041, 860, 814]
# Numero scambi seconda euristica: 0
# ITERATION 6
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 7
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 8
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 9
# Numero di scambi prima euristica: 3
# Numero scambi seconda euristica: 3
# ITERATION 10
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 11
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 12
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 13
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 14
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 15
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 16
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 17
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 18
# Numero di scambi prima euristica: 2
# Numero scambi seconda euristica: 2
# ITERATION 19
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 20
# Numero di scambi prima euristica: 6
# Numero scambi seconda euristica: 6
# ITERATION 21
# Numero di scambi prima euristica: 8
# Numero scambi seconda euristica: 17
# ITERATION 22
# Numero di scambi prima euristica: 10
# Numero scambi seconda euristica: 17
# ITERATION 23
# Numero di scambi prima euristica: 10
# Numero scambi seconda euristica: 17
# ITERATION 24
# System overloaded. 4091 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 1593 richieste rigettate
# System overloaded
# 2498 richieste rigettate
# Numero scambi seconda euristica: 21
# ITERATION 25
# System overloaded. 3918 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 1428 richieste rigettate
# System overloaded
# 2490 richieste rigettate
# Numero scambi seconda euristica: 22
# ITERATION 26
# System overloaded. 2883 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 1493 richieste rigettate
# System overloaded
# 1390 richieste rigettate
# Numero scambi seconda euristica: 19
# ITERATION 27
# System overloaded. 635 richieste rigettate
# Numero di scambi prima euristica: 17
# System overloaded
# 635 richieste rigettate
# Numero scambi seconda euristica: 20
# ITERATION 28
# Numero di scambi prima euristica: 8
# Numero scambi seconda euristica: 17
# ITERATION 29
# Numero di scambi prima euristica: 7
# Numero scambi seconda euristica: 17
# ITERATION 30
# Numero di scambi prima euristica: 6
# Numero scambi seconda euristica: 28
# ITERATION 31
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 4
# ITERATION 32
# Numero di scambi prima euristica: 4
# Numero scambi seconda euristica: 17
# ITERATION 33
# Numero di scambi prima euristica: 7
# Numero scambi seconda euristica: 17
# ITERATION 34
# Numero di scambi prima euristica: 8
# Numero scambi seconda euristica: 25
# ITERATION 35
# No changing required: [9156, 6029, 5247, 4462, 4410, 4033, 3108, 2678, 2329, 1995, 1805, 1606, 1563, 1304, 1163, 1147, 1120, 979]
# Numero scambi seconda euristica: 0
